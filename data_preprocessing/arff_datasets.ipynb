# %%
from typing import List, Dict, Tuple, Any
import argparse

try:
    from .utils import isnotebook
except ImportError:
    try:
        from utils import isnotebook
    except:
        isnotebook = lambda: True
from pathlib import Path
import json
import sys
sys.path.append('../')
from skmultilearn.dataset import load_from_arff

# %%
def get_args() -> argparse.Namespace:
    parser = argparse.ArgumentParser(
        description="Read an .arff dataset file"
    )
    parser.add_argument("-i", "--input-file", type=Path)
    parser.add_argument(
        "-f",
        "--format",
        default="meka",
        choices=['meka', 'mulan'],
        help="Format. See http://scikit.ml/datasets.html#ARFF-files",
    )
    if isnotebook():
        import shlex  # noqa

        args_str = (
            "-i ../.data/bibtex_meka/all.arff"
        )
        args = parser.parse_args(shlex.split(args_str))
    else:
        args = parser.parse_args()
    return args

# %%
#def main(args: argparse.Namespace)->None:
args = get_args()

# %%
X, y, feature_names, label_names =load_from_arff(args.input_file, label_count=159, return_attribute_definitions=True)

# %%
y
# Out:
# <7395x159 sparse matrix of type '<class 'numpy.int64'>'
# 	with 17762 stored elements in List of Lists format>

# %%
label_names
# Out:
# [('TAG_2005', ['0', '1']),
#  ('TAG_2006', ['0', '1']),
#  ('TAG_2007', ['0', '1']),
#  ('TAG_agdetection', ['0', '1']),
#  ('TAG_algorithms', ['0', '1']),
#  ('TAG_amperometry', ['0', '1']),
#  ('TAG_analysis', ['0', '1']),
#  ('TAG_and', ['0', '1']),
#  ('TAG_annotation', ['0', '1']),
#  ('TAG_antibody', ['0', '1']),
#  ('TAG_apob', ['0', '1']),
#  ('TAG_architecture', ['0', '1']),
#  ('TAG_article', ['0', '1']),
#  ('TAG_bettasplendens', ['0', '1']),
#  ('TAG_bibteximport', ['0', '1']),
#  ('TAG_book', ['0', '1']),
#  ('TAG_children', ['0', '1']),
#  ('TAG_classification', ['0', '1']),
#  ('TAG_clustering', ['0', '1']),
#  ('TAG_cognition', ['0', '1']),
#  ('TAG_collaboration', ['0', '1']),
#  ('TAG_collaborative', ['0', '1']),
#  ('TAG_community', ['0', '1']),
#  ('TAG_competition', ['0', '1']),
#  ('TAG_complex', ['0', '1']),
#  ('TAG_complexity', ['0', '1']),
#  ('TAG_compounds', ['0', '1']),
#  ('TAG_computer', ['0', '1']),
#  ('TAG_computing', ['0', '1']),
#  ('TAG_concept', ['0', '1']),
#  ('TAG_context', ['0', '1']),
#  ('TAG_cortex', ['0', '1']),
#  ('TAG_critical', ['0', '1']),
#  ('TAG_data', ['0', '1']),
#  ('TAG_datamining', ['0', '1']),
#  ('TAG_date', ['0', '1']),
#  ('TAG_design', ['0', '1']),
#  ('TAG_development', ['0', '1']),
#  ('TAG_diffusion', ['0', '1']),
#  ('TAG_diplomathesis', ['0', '1']),
#  ('TAG_disability', ['0', '1']),
#  ('TAG_dynamics', ['0', '1']),
#  ('TAG_education', ['0', '1']),
#  ('TAG_elearning', ['0', '1']),
#  ('TAG_electrochemistry', ['0', '1']),
#  ('TAG_elisa', ['0', '1']),
#  ('TAG_empirical', ['0', '1']),
#  ('TAG_energy', ['0', '1']),
#  ('TAG_engineering', ['0', '1']),
#  ('TAG_epitope', ['0', '1']),
#  ('TAG_equation', ['0', '1']),
#  ('TAG_evaluation', ['0', '1']),
#  ('TAG_evolution', ['0', '1']),
#  ('TAG_fca', ['0', '1']),
#  ('TAG_folksonomy', ['0', '1']),
#  ('TAG_formal', ['0', '1']),
#  ('TAG_fornepomuk', ['0', '1']),
#  ('TAG_games', ['0', '1']),
#  ('TAG_granular', ['0', '1']),
#  ('TAG_graph', ['0', '1']),
#  ('TAG_hci', ['0', '1']),
#  ('TAG_homogeneous', ['0', '1']),
#  ('TAG_imaging', ['0', '1']),
#  ('TAG_immunoassay', ['0', '1']),
#  ('TAG_immunoelectrode', ['0', '1']),
#  ('TAG_immunosensor', ['0', '1']),
#  ('TAG_information', ['0', '1']),
#  ('TAG_informationretrieval', ['0', '1']),
#  ('TAG_kaldesignresearch', ['0', '1']),
#  ('TAG_kinetic', ['0', '1']),
#  ('TAG_knowledge', ['0', '1']),
#  ('TAG_knowledgemanagement', ['0', '1']),
#  ('TAG_langen', ['0', '1']),
#  ('TAG_language', ['0', '1']),
#  ('TAG_ldl', ['0', '1']),
#  ('TAG_learning', ['0', '1']),
#  ('TAG_liposome', ['0', '1']),
#  ('TAG_litreview', ['0', '1']),
#  ('TAG_logic', ['0', '1']),
#  ('TAG_maintenance', ['0', '1']),
#  ('TAG_management', ['0', '1']),
#  ('TAG_mapping', ['0', '1']),
#  ('TAG_marotzkiwinfried', ['0', '1']),
#  ('TAG_mathematics', ['0', '1']),
#  ('TAG_mathgamespatterns', ['0', '1']),
#  ('TAG_methodology', ['0', '1']),
#  ('TAG_metrics', ['0', '1']),
#  ('TAG_mining', ['0', '1']),
#  ('TAG_model', ['0', '1']),
#  ('TAG_modeling', ['0', '1']),
#  ('TAG_models', ['0', '1']),
#  ('TAG_molecular', ['0', '1']),
#  ('TAG_montecarlo', ['0', '1']),
#  ('TAG_myown', ['0', '1']),
#  ('TAG_narrative', ['0', '1']),
#  ('TAG_nepomuk', ['0', '1']),
#  ('TAG_network', ['0', '1']),
#  ('TAG_networks', ['0', '1']),
#  ('TAG_nlp', ['0', '1']),
#  ('TAG_nonequilibrium', ['0', '1']),
#  ('TAG_notag', ['0', '1']),
#  ('TAG_objectoriented', ['0', '1']),
#  ('TAG_of', ['0', '1']),
#  ('TAG_ontologies', ['0', '1']),
#  ('TAG_ontology', ['0', '1']),
#  ('TAG_pattern', ['0', '1']),
#  ('TAG_patterns', ['0', '1']),
#  ('TAG_phase', ['0', '1']),
#  ('TAG_physics', ['0', '1']),
#  ('TAG_process', ['0', '1']),
#  ('TAG_programming', ['0', '1']),
#  ('TAG_prolearn', ['0', '1']),
#  ('TAG_psycholinguistics', ['0', '1']),
#  ('TAG_quantum', ['0', '1']),
#  ('TAG_random', ['0', '1']),
#  ('TAG_rdf', ['0', '1']),
#  ('TAG_representation', ['0', '1']),
#  ('TAG_requirements', ['0', '1']),
#  ('TAG_research', ['0', '1']),
#  ('TAG_review', ['0', '1']),
#  ('TAG_science', ['0', '1']),
#  ('TAG_search', ['0', '1']),
#  ('TAG_semantic', ['0', '1']),
#  ('TAG_semantics', ['0', '1']),
#  ('TAG_semanticweb', ['0', '1']),
#  ('TAG_sequence', ['0', '1']),
#  ('TAG_simulation', ['0', '1']),
#  ('TAG_simulations', ['0', '1']),
#  ('TAG_sna', ['0', '1']),
#  ('TAG_social', ['0', '1']),
#  ('TAG_socialnets', ['0', '1']),
#  ('TAG_software', ['0', '1']),
#  ('TAG_spin', ['0', '1']),
#  ('TAG_statistics', ['0', '1']),
#  ('TAG_statphys23', ['0', '1']),
#  ('TAG_structure', ['0', '1']),
#  ('TAG_survey', ['0', '1']),
#  ('TAG_system', ['0', '1']),
#  ('TAG_systems', ['0', '1']),
#  ('TAG_tagging', ['0', '1']),
#  ('TAG_technology', ['0', '1']),
#  ('TAG_theory', ['0', '1']),
#  ('TAG_topic1', ['0', '1']),
#  ('TAG_topic10', ['0', '1']),
#  ('TAG_topic11', ['0', '1']),
#  ('TAG_topic2', ['0', '1']),
#  ('TAG_topic3', ['0', '1']),
#  ('TAG_topic4', ['0', '1']),
#  ('TAG_topic6', ['0', '1']),
#  ('TAG_topic7', ['0', '1']),
#  ('TAG_topic8', ['0', '1']),
#  ('TAG_topic9', ['0', '1']),
#  ('TAG_toread', ['0', '1']),
#  ('TAG_transition', ['0', '1']),
#  ('TAG_visual', ['0', '1']),
#  ('TAG_visualization', ['0', '1']),
#  ('TAG_web', ['0', '1']),
#  ('TAG_web20', ['0', '1']),
#  ('TAG_wiki', ['0', '1'])]

# %%
feature_names
# Out:
# [('0', ['0', '1']),
#  ('000', ['0', '1']),
#  ('02', ['0', '1']),
#  ('05', ['0', '1']),
#  ('06', ['0', '1']),
#  ('1', ['0', '1']),
#  ('10', ['0', '1']),
#  ('100', ['0', '1']),
#  ('11', ['0', '1']),
#  ('12', ['0', '1']),
#  ('13', ['0', '1']),
#  ('14', ['0', '1']),
#  ('15', ['0', '1']),
#  ('16', ['0', '1']),
#  ('17', ['0', '1']),
#  ('18', ['0', '1']),
#  ('1997', ['0', '1']),
#  ('1998', ['0', '1']),
#  ('1999', ['0', '1']),
#  ('2', ['0', '1']),
#  ('20', ['0', '1']),
#  ('2000', ['0', '1']),
#  ('2001', ['0', '1']),
#  ('2002', ['0', '1']),
#  ('2003', ['0', '1']),
#  ('2004', ['0', '1']),
#  ('2005', ['0', '1']),
#  ('2006', ['0', '1']),
#  ('2007', ['0', '1']),
#  ('24', ['0', '1']),
#  ('25', ['0', '1']),
#  ('3', ['0', '1']),
#  ('30', ['0', '1']),
#  ('4', ['0', '1']),
#  ('40', ['0', '1']),
#  ('5', ['0', '1']),
#  ('50', ['0', '1']),
#  ('6', ['0', '1']),
#  ('60', ['0', '1']),
#  ('7', ['0', '1']),
#  ('8', ['0', '1']),
#  ('9', ['0', '1']),
#  ('95', ['0', '1']),
#  ('98', ['0', '1']),
#  ('a', ['0', '1']),
#  ('ab', ['0', '1']),
#  ('ability', ['0', '1']),
#  ('able', ['0', '1']),
#  ('about', ['0', '1']),
#  ('above', ['0', '1']),
#  ('absence', ['0', '1']),
#  ('abstract', ['0', '1']),
#  ('academic', ['0', '1']),
#  ('access', ['0', '1']),
#  ('accessible', ['0', '1']),
#  ('according', ['0', '1']),
#  ('account', ['0', '1']),
#  ('accuracy', ['0', '1']),
#  ('accurate', ['0', '1']),
#  ('achieve', ['0', '1']),
#  ('achieved', ['0', '1']),
#  ('acid', ['0', '1']),
#  ('acids', ['0', '1']),
#  ('acm', ['0', '1']),
#  ('acquisition', ['0', '1']),
#  ('across', ['0', '1']),
#  ('act', ['0', '1']),
#  ('action', ['0', '1']),
#  ('activation', ['0', '1']),
#  ('active', ['0', '1']),
#  ('activities', ['0', '1']),
#  ('activity', ['0', '1']),
#  ('actual', ['0', '1']),
#  ('adaptation', ['0', '1']),
#  ('adapted', ['0', '1']),
#  ('adaptive', ['0', '1']),
#  ('added', ['0', '1']),
#  ('addition', ['0', '1']),
#  ('additional', ['0', '1']),
#  ('address', ['0', '1']),
#  ('addressed', ['0', '1']),
#  ('addresses', ['0', '1']),
#  ('advanced', ['0', '1']),
#  ('advances', ['0', '1']),
#  ('advantage', ['0', '1']),
#  ('advantages', ['0', '1']),
#  ('affect', ['0', '1']),
#  ('affected', ['0', '1']),
#  ('affinity', ['0', '1']),
#  ('after', ['0', '1']),
#  ('against', ['0', '1']),
#  ('age', ['0', '1']),
#  ('agent', ['0', '1']),
#  ('agents', ['0', '1']),
#  ('agreement', ['0', '1']),
#  ('aim', ['0', '1']),
#  ('aims', ['0', '1']),
#  ('al', ['0', '1']),
#  ('algorithm', ['0', '1']),
#  ('algorithms', ['0', '1']),
#  ('all', ['0', '1']),
#  ('allow', ['0', '1']),
#  ('allowed', ['0', '1']),
#  ('allowing', ['0', '1']),
#  ('allows', ['0', '1']),
#  ('almost', ['0', '1']),
#  ('along', ['0', '1']),
#  ('alpha', ['0', '1']),
#  ('already', ['0', '1']),
#  ('als', ['0', '1']),
#  ('also', ['0', '1']),
#  ('alternative', ['0', '1']),
#  ('although', ['0', '1']),
#  ('always', ['0', '1']),
#  ('am', ['0', '1']),
#  ('american', ['0', '1']),
#  ('amino', ['0', '1']),
#  ('among', ['0', '1']),
#  ('amount', ['0', '1']),
#  ('amounts', ['0', '1']),
#  ('amperometric', ['0', '1']),
#  ('an', ['0', '1']),
#  ('analyse', ['0', '1']),
#  ('analyses', ['0', '1']),
#  ('analysis', ['0', '1']),
#  ('analytical', ['0', '1']),
#  ('analyze', ['0', '1']),
#  ('analyzed', ['0', '1']),
#  ('analyzing', ['0', '1']),
#  ('and', ['0', '1']),
#  ('annotation', ['0', '1']),
#  ('annual', ['0', '1']),
#  ('another', ['0', '1']),
#  ('answer', ['0', '1']),
#  ('anti', ['0', '1']),
#  ('antibodies', ['0', '1']),
#  ('antibody', ['0', '1']),
#  ('antigen', ['0', '1']),
#  ('any', ['0', '1']),
#  ('apo', ['0', '1']),
#  ('apob', ['0', '1']),
#  ('apolipoprotein', ['0', '1']),
#  ('apparent', ['0', '1']),
#  ('appear', ['0', '1']),
#  ('appears', ['0', '1']),
#  ('applicable', ['0', '1']),
#  ('application', ['0', '1']),
#  ('applications', ['0', '1']),
#  ('applied', ['0', '1']),
#  ('apply', ['0', '1']),
#  ('applying', ['0', '1']),
#  ('approach', ['0', '1']),
#  ('approaches', ['0', '1']),
#  ('appropriate', ['0', '1']),
#  ('approximate', ['0', '1']),
#  ('approximately', ['0', '1']),
#  ('approximation', ['0', '1']),
#  ('aqueous', ['0', '1']),
#  ('arbitrary', ['0', '1']),
#  ('architecture', ['0', '1']),
#  ('architectures', ['0', '1']),
#  ('are', ['0', '1']),
#  ('area', ['0', '1']),
#  ('areas', ['0', '1']),
#  ('argue', ['0', '1']),
#  ('argued', ['0', '1']),
#  ('arguments', ['0', '1']),
#  ('arise', ['0', '1']),
#  ('around', ['0', '1']),
#  ('art', ['0', '1']),
#  ('article', ['0', '1']),
#  ('articles', ['0', '1']),
#  ('artificial', ['0', '1']),
#  ('as', ['0', '1']),
#  ('aspect', ['0', '1']),
#  ('aspects', ['0', '1']),
#  ('assay', ['0', '1']),
#  ('assays', ['0', '1']),
#  ('assess', ['0', '1']),
#  ('assessed', ['0', '1']),
#  ('assessment', ['0', '1']),
#  ('associated', ['0', '1']),
#  ('association', ['0', '1']),
#  ('assumption', ['0', '1']),
#  ('assumptions', ['0', '1']),
#  ('at', ['0', '1']),
#  ('atomic', ['0', '1']),
#  ('atoms', ['0', '1']),
#  ('attempt', ['0', '1']),
#  ('attention', ['0', '1']),
#  ('attractive', ['0', '1']),
#  ('auch', ['0', '1']),
#  ('auf', ['0', '1']),
#  ('author', ['0', '1']),
#  ('authors', ['0', '1']),
#  ('automated', ['0', '1']),
#  ('automatic', ['0', '1']),
#  ('automatically', ['0', '1']),
#  ('automation', ['0', '1']),
#  ('availability', ['0', '1']),
#  ('available', ['0', '1']),
#  ('average', ['0', '1']),
#  ('aware', ['0', '1']),
#  ('b', ['0', '1']),
#  ('back', ['0', '1']),
#  ('background', ['0', '1']),
#  ('barrier', ['0', '1']),
#  ('base', ['0', '1']),
#  ('based', ['0', '1']),
#  ('bases', ['0', '1']),
#  ('basic', ['0', '1']),
#  ('basis', ['0', '1']),
#  ('be', ['0', '1']),
#  ('because', ['0', '1']),
#  ('become', ['0', '1']),
#  ('becomes', ['0', '1']),
#  ('been', ['0', '1']),
#  ('before', ['0', '1']),
#  ('begin', ['0', '1']),
#  ('behavior', ['0', '1']),
#  ('behavioral', ['0', '1']),
#  ('behaviors', ['0', '1']),
#  ('behaviour', ['0', '1']),
#  ('being', ['0', '1']),
#  ('believe', ['0', '1']),
#  ('below', ['0', '1']),
#  ('benefit', ['0', '1']),
#  ('benefits', ['0', '1']),
#  ('ber', ['0', '1']),
#  ('best', ['0', '1']),
#  ('beta', ['0', '1']),
#  ('betta', ['0', '1']),
#  ('better', ['0', '1']),
#  ('between', ['0', '1']),
#  ('beyond', ['0', '1']),
#  ('binding', ['0', '1']),
#  ('bioinformatics', ['0', '1']),
#  ('biol', ['0', '1']),
#  ('biological', ['0', '1']),
#  ('biology', ['0', '1']),
#  ('body', ['0', '1']),
#  ('boltzmann', ['0', '1']),
#  ('bond', ['0', '1']),
#  ('book', ['0', '1']),
#  ('both', ['0', '1']),
#  ('bound', ['0', '1']),
#  ('boundary', ['0', '1']),
#  ('brain', ['0', '1']),
#  ('brief', ['0', '1']),
#  ('briefly', ['0', '1']),
#  ('broad', ['0', '1']),
#  ('build', ['0', '1']),
#  ('building', ['0', '1']),
#  ('built', ['0', '1']),
#  ('bulk', ['0', '1']),
#  ('business', ['0', '1']),
#  ('but', ['0', '1']),
#  ('by', ['0', '1']),
#  ('c', ['0', '1']),
#  ('calculate', ['0', '1']),
#  ('calculated', ['0', '1']),
#  ('calculation', ['0', '1']),
#  ('calculations', ['0', '1']),
#  ('call', ['0', '1']),
#  ('called', ['0', '1']),
#  ('can', ['0', '1']),
#  ('cannot', ['0', '1']),
#  ('capabilities', ['0', '1']),
#  ('capable', ['0', '1']),
#  ('capacity', ['0', '1']),
#  ('capture', ['0', '1']),
#  ('carbon', ['0', '1']),
#  ('care', ['0', '1']),
#  ('carlo', ['0', '1']),
#  ('carried', ['0', '1']),
#  ('case', ['0', '1']),
#  ('cases', ['0', '1']),
#  ('catalytic', ['0', '1']),
#  ('categories', ['0', '1']),
#  ('cause', ['0', '1']),
#  ('caused', ['0', '1']),
#  ('cell', ['0', '1']),
#  ('cells', ['0', '1']),
#  ('center', ['0', '1']),
#  ('central', ['0', '1']),
#  ('century', ['0', '1']),
#  ('certain', ['0', '1']),
#  ('chain', ['0', '1']),
#  ('chains', ['0', '1']),
#  ('challenge', ['0', '1']),
#  ('challenges', ['0', '1']),
#  ('change', ['0', '1']),
#  ('changes', ['0', '1']),
#  ('changing', ['0', '1']),
#  ('character', ['0', '1']),
#  ('characteristic', ['0', '1']),
#  ('characteristics', ['0', '1']),
#  ('characterization', ['0', '1']),
#  ('characterize', ['0', '1']),
#  ('characterized', ['0', '1']),
#  ('charge', ['0', '1']),
#  ('charged', ['0', '1']),
#  ('chem', ['0', '1']),
#  ('chemical', ['0', '1']),
#  ('chemistry', ['0', '1']),
#  ('child', ['0', '1']),
#  ('children', ['0', '1']),
#  ('choice', ['0', '1']),
#  ('cholesterol', ['0', '1']),
#  ('chosen', ['0', '1']),
#  ('class', ['0', '1']),
#  ('classes', ['0', '1']),
#  ('classical', ['0', '1']),
#  ('classification', ['0', '1']),
#  ('clear', ['0', '1']),
#  ('clearly', ['0', '1']),
#  ('clin', ['0', '1']),
#  ('clinical', ['0', '1']),
#  ('close', ['0', '1']),
#  ('cluster', ['0', '1']),
#  ('clustering', ['0', '1']),
#  ('clusters', ['0', '1']),
#  ('co', ['0', '1']),
#  ('code', ['0', '1']),
#  ('coefficient', ['0', '1']),
#  ('coefficients', ['0', '1']),
#  ('cognitive', ['0', '1']),
#  ('collaboration', ['0', '1']),
#  ('collaborative', ['0', '1']),
#  ('collected', ['0', '1']),
#  ('collection', ['0', '1']),
#  ('combination', ['0', '1']),
#  ('combined', ['0', '1']),
#  ('combines', ['0', '1']),
#  ('combining', ['0', '1']),
#  ('commercial', ['0', '1']),
#  ('common', ['0', '1']),
#  ('commonly', ['0', '1']),
#  ('communication', ['0', '1']),
#  ('communications', ['0', '1']),
#  ('communities', ['0', '1']),
#  ('community', ['0', '1']),
#  ('comparable', ['0', '1']),
#  ('comparative', ['0', '1']),
#  ('compare', ['0', '1']),
#  ('compared', ['0', '1']),
#  ('comparing', ['0', '1']),
#  ('comparison', ['0', '1']),
#  ('competition', ['0', '1']),
#  ('competitive', ['0', '1']),
#  ('complete', ['0', '1']),
#  ('completely', ['0', '1']),
#  ('complex', ['0', '1']),
#  ('complexes', ['0', '1']),
#  ('complexity', ['0', '1']),
#  ('component', ['0', '1']),
#  ('components', ['0', '1']),
#  ('composed', ['0', '1']),
#  ('composition', ['0', '1']),
#  ('compounds', ['0', '1']),
#  ('comprehensive', ['0', '1']),
#  ('computation', ['0', '1']),
#  ('computational', ['0', '1']),
#  ('computed', ['0', '1']),
#  ('computer', ['0', '1']),
#  ('computers', ['0', '1']),
#  ('computing', ['0', '1']),
#  ('concentration', ['0', '1']),
#  ('concentrations', ['0', '1']),
#  ('concept', ['0', '1']),
#  ('concepts', ['0', '1']),
#  ('conceptual', ['0', '1']),
#  ('concerning', ['0', '1']),
#  ('concerns', ['0', '1']),
#  ('conclude', ['0', '1']),
#  ('conclusion', ['0', '1']),
#  ('conclusions', ['0', '1']),
#  ('condition', ['0', '1']),
#  ('conditions', ['0', '1']),
#  ('conducted', ['0', '1']),
#  ('conf', ['0', '1']),
#  ('conference', ['0', '1']),
#  ('configuration', ['0', '1']),
#  ('confirmed', ['0', '1']),
#  ('connected', ['0', '1']),
#  ('connection', ['0', '1']),
#  ('connections', ['0', '1']),
#  ('consequence', ['0', '1']),
#  ('consequences', ['0', '1']),
#  ('consider', ['0', '1']),
#  ('considerable', ['0', '1']),
#  ('considered', ['0', '1']),
#  ('considering', ['0', '1']),
#  ('consistent', ['0', '1']),
#  ('consisting', ['0', '1']),
#  ('consists', ['0', '1']),
#  ('constant', ['0', '1']),
#  ('constants', ['0', '1']),
#  ('constraints', ['0', '1']),
#  ('construct', ['0', '1']),
#  ('constructed', ['0', '1']),
#  ('construction', ['0', '1']),
#  ('consumption', ['0', '1']),
#  ('contact', ['0', '1']),
#  ('contain', ['0', '1']),
#  ('contained', ['0', '1']),
#  ('containing', ['0', '1']),
#  ('contains', ['0', '1']),
#  ('content', ['0', '1']),
#  ('context', ['0', '1']),
#  ('contexts', ['0', '1']),
#  ('continuous', ['0', '1']),
#  ('contrast', ['0', '1']),
#  ('contribute', ['0', '1']),
#  ('contribution', ['0', '1']),
#  ('contributions', ['0', '1']),
#  ('control', ['0', '1']),
#  ('controlled', ['0', '1']),
#  ('conventional', ['0', '1']),
#  ('cooperative', ['0', '1']),
#  ('core', ['0', '1']),
#  ('correct', ['0', '1']),
#  ('correlated', ['0', '1']),
#  ('correlation', ['0', '1']),
#  ('correlations', ['0', '1']),
#  ('corresponding', ['0', '1']),
#  ('cortex', ['0', '1']),
#  ('cost', ['0', '1']),
#  ('could', ['0', '1']),
#  ('coupled', ['0', '1']),
#  ('coupling', ['0', '1']),
#  ('course', ['0', '1']),
#  ('create', ['0', '1']),
#  ('created', ['0', '1']),
#  ('creating', ['0', '1']),
#  ('creation', ['0', '1']),
#  ('criteria', ['0', '1']),
#  ('critical', ['0', '1']),
#  ('cross', ['0', '1']),
#  ('crucial', ['0', '1']),
#  ('crystal', ['0', '1']),
#  ('cultural', ['0', '1']),
#  ('culture', ['0', '1']),
#  ('current', ['0', '1']),
#  ('currently', ['0', '1']),
#  ('curves', ['0', '1']),
#  ('cycle', ['0', '1']),
#  ('d', ['0', '1']),
#  ('daily', ['0', '1']),
#  ('das', ['0', '1']),
#  ('data', ['0', '1']),
#  ('database', ['0', '1']),
#  ('databases', ['0', '1']),
#  ('date', ['0', '1']),
#  ('day', ['0', '1']),
#  ('de', ['0', '1']),
#  ('deal', ['0', '1']),
#  ('decision', ['0', '1']),
#  ('decisions', ['0', '1']),
#  ('decrease', ['0', '1']),
#  ('decreased', ['0', '1']),
#  ('define', ['0', '1']),
#  ('defined', ['0', '1']),
#  ('defining', ['0', '1']),
#  ('definition', ['0', '1']),
#  ('degree', ['0', '1']),
#  ('degrees', ['0', '1']),
#  ('dem', ['0', '1']),
#  ('demonstrate', ['0', '1']),
#  ('demonstrated', ['0', '1']),
#  ('demonstrates', ['0', '1']),
#  ('den', ['0', '1']),
#  ('density', ['0', '1']),
#  ('depend', ['0', '1']),
#  ('dependence', ['0', '1']),
#  ('dependent', ['0', '1']),
#  ('depending', ['0', '1']),
#  ('depends', ['0', '1']),
#  ('der', ['0', '1']),
#  ('derive', ['0', '1']),
#  ('derived', ['0', '1']),
#  ('des', ['0', '1']),
#  ('describe', ['0', '1']),
#  ('described', ['0', '1']),
#  ('describes', ['0', '1']),
#  ('describing', ['0', '1']),
#  ('description', ['0', '1']),
#  ('descriptions', ['0', '1']),
#  ('design', ['0', '1']),
#  ('designed', ['0', '1']),
#  ('designing', ['0', '1']),
#  ('despite', ['0', '1']),
#  ('detail', ['0', '1']),
#  ('detailed', ['0', '1']),
#  ('details', ['0', '1']),
#  ('detect', ['0', '1']),
#  ('detected', ['0', '1']),
#  ('detection', ['0', '1']),
#  ('determination', ['0', '1']),
#  ('determine', ['0', '1']),
#  ('determined', ['0', '1']),
#  ('determining', ['0', '1']),
#  ('develop', ['0', '1']),
#  ('developed', ['0', '1']),
#  ('developers', ['0', '1']),
#  ('developing', ['0', '1']),
#  ('development', ['0', '1']),
#  ('developmental', ['0', '1']),
#  ('developments', ['0', '1']),
#  ('device', ['0', '1']),
#  ('devices', ['0', '1']),
#  ('dft', ['0', '1']),
#  ('diagram', ['0', '1']),
#  ('did', ['0', '1']),
#  ('die', ['0', '1']),
#  ('differ', ['0', '1']),
#  ('difference', ['0', '1']),
#  ('differences', ['0', '1']),
#  ('different', ['0', '1']),
#  ('differential', ['0', '1']),
#  ('difficult', ['0', '1']),
#  ('diffusion', ['0', '1']),
#  ('digital', ['0', '1']),
#  ('dimension', ['0', '1']),
#  ('dimensional', ['0', '1']),
#  ('dimensions', ['0', '1']),
#  ('direct', ['0', '1']),
#  ('directed', ['0', '1']),
#  ('direction', ['0', '1']),
#  ('directions', ['0', '1']),
#  ('directly', ['0', '1']),
#  ('discovery', ['0', '1']),
#  ('discrete', ['0', '1']),
#  ('discuss', ['0', '1']),
#  ('discussed', ['0', '1']),
#  ('discusses', ['0', '1']),
#  ('discussion', ['0', '1']),
#  ('disease', ['0', '1']),
#  ('disorder', ['0', '1']),
#  ('display', ['0', '1']),
#  ('distance', ['0', '1']),
#  ('distinct', ['0', '1']),
#  ('distributed', ['0', '1']),
#  ('distribution', ['0', '1']),
#  ('distributions', ['0', '1']),
#  ('diverse', ['0', '1']),
#  ('dna', ['0', '1']),
#  ('do', ['0', '1']),
#  ('document', ['0', '1']),
#  ('documents', ['0', '1']),
#  ('does', ['0', '1']),
#  ('domain', ['0', '1']),
#  ('domains', ['0', '1']),
#  ('done', ['0', '1']),
#  ('double', ['0', '1']),
#  ('down', ['0', '1']),
#  ('driven', ['0', '1']),
#  ('due', ['0', '1']),
#  ('during', ['0', '1']),
#  ('dynamic', ['0', '1']),
#  ('dynamical', ['0', '1']),
#  ('dynamics', ['0', '1']),
#  ('e', ['0', '1']),
#  ('each', ['0', '1']),
#  ('earlier', ['0', '1']),
#  ('early', ['0', '1']),
#  ('easily', ['0', '1']),
#  ('easy', ['0', '1']),
#  ('economic', ['0', '1']),
#  ('education', ['0', '1']),
#  ('educational', ['0', '1']),
#  ('effect', ['0', '1']),
#  ('effective', ['0', '1']),
#  ('effectively', ['0', '1']),
#  ('effectiveness', ['0', '1']),
#  ('effects', ['0', '1']),
#  ('efficiency', ['0', '1']),
#  ('efficient', ['0', '1']),
#  ('efficiently', ['0', '1']),
#  ('effort', ['0', '1']),
#  ('efforts', ['0', '1']),
#  ('ein', ['0', '1']),
#  ('eine', ['0', '1']),
#  ('einer', ['0', '1']),
#  ('either', ['0', '1']),
#  ('electrochemical', ['0', '1']),
#  ('electrode', ['0', '1']),
#  ('electron', ['0', '1']),
#  ('electronic', ['0', '1']),
#  ('electrostatic', ['0', '1']),
#  ('elements', ['0', '1']),
#  ('embedded', ['0', '1']),
#  ('emergence', ['0', '1']),
#  ('emerging', ['0', '1']),
#  ('emphasis', ['0', '1']),
#  ('empirical', ['0', '1']),
#  ('employed', ['0', '1']),
#  ('en', ['0', '1']),
#  ('enable', ['0', '1']),
#  ('enables', ['0', '1']),
#  ('enabling', ['0', '1']),
#  ('end', ['0', '1']),
#  ('energies', ['0', '1']),
#  ('energy', ['0', '1']),
#  ('engine', ['0', '1']),
#  ('engineering', ['0', '1']),
#  ('enhance', ['0', '1']),
#  ('enhanced', ['0', '1']),
#  ('enough', ['0', '1']),
#  ('entire', ['0', '1']),
#  ('entities', ['0', '1']),
#  ('entropy', ['0', '1']),
#  ('environment', ['0', '1']),
#  ('environments', ['0', '1']),
#  ('enzyme', ['0', '1']),
#  ('enzymes', ['0', '1']),
#  ('equal', ['0', '1']),
#  ('equation', ['0', '1']),
#  ('equations', ['0', '1']),
#  ('equilibrium', ['0', '1']),
#  ('equivalent', ['0', '1']),
#  ('er', ['0', '1']),
#  ('error', ['0', '1']),
#  ('errors', ['0', '1']),
#  ('es', ['0', '1']),
#  ('especially', ['0', '1']),
#  ('essential', ['0', '1']),
#  ('establish', ['0', '1']),
#  ('established', ['0', '1']),
#  ('estimate', ['0', '1']),
#  ('estimated', ['0', '1']),
#  ('estimates', ['0', '1']),
#  ('estimation', ['0', '1']),
#  ('et', ['0', '1']),
#  ('etc', ['0', '1']),
#  ('european', ['0', '1']),
#  ('evaluate', ['0', '1']),
#  ('evaluated', ['0', '1']),
#  ('evaluating', ['0', '1']),
#  ('evaluation', ['0', '1']),
#  ('even', ['0', '1']),
#  ('event', ['0', '1']),
#  ('events', ['0', '1']),
#  ('every', ['0', '1']),
#  ('evidence', ['0', '1']),
#  ('evolution', ['0', '1']),
#  ('evolutionary', ['0', '1']),
#  ('evolving', ['0', '1']),
#  ('exact', ['0', '1']),
#  ('examine', ['0', '1']),
#  ('examined', ['0', '1']),
#  ('examines', ['0', '1']),
#  ('example', ['0', '1']),
#  ('examples', ['0', '1']),
#  ('excellent', ['0', '1']),
#  ('exchange', ['0', '1']),
#  ('execution', ['0', '1']),
#  ('exhibit', ['0', '1']),
#  ('exhibits', ['0', '1']),
#  ('exist', ['0', '1']),
#  ('existence', ['0', '1']),
#  ('existing', ['0', '1']),
#  ('exists', ['0', '1']),
#  ('expansion', ['0', '1']),
#  ('expected', ['0', '1']),
#  ('experience', ['0', '1']),
#  ('experiences', ['0', '1']),
#  ('experiment', ['0', '1']),
#  ('experimental', ['0', '1']),
#  ('experimentally', ['0', '1']),
#  ('experiments', ['0', '1']),
#  ('explain', ['0', '1']),
#  ('explained', ['0', '1']),
#  ('explanation', ['0', '1']),
#  ('explicit', ['0', '1']),
#  ('explicitly', ['0', '1']),
#  ('exploration', ['0', '1']),
#  ('explore', ['0', '1']),
#  ('explored', ['0', '1']),
#  ('explores', ['0', '1']),
#  ('exploring', ['0', '1']),
#  ('exponent', ['0', '1']),
#  ('exponents', ['0', '1']),
#  ('expressed', ['0', '1']),
#  ('expression', ['0', '1']),
#  ('extend', ['0', '1']),
#  ('extended', ['0', '1']),
#  ('extension', ['0', '1']),
#  ('extensive', ['0', '1']),
#  ('extent', ['0', '1']),
#  ('external', ['0', '1']),
#  ('extraction', ['0', '1']),
#  ('f', ['0', '1']),
#  ('face', ['0', '1']),
#  ('facilitate', ['0', '1']),
#  ('fact', ['0', '1']),
#  ('factor', ['0', '1']),
#  ('factors', ['0', '1']),
#  ('family', ['0', '1']),
#  ('far', ['0', '1']),
#  ('fast', ['0', '1']),
#  ('faster', ['0', '1']),
#  ('feature', ['0', '1']),
#  ('features', ['0', '1']),
#  ('feedback', ['0', '1']),
#  ('few', ['0', '1']),
#  ('field', ['0', '1']),
#  ('fields', ['0', '1']),
#  ('fighting', ['0', '1']),
#  ('final', ['0', '1']),
#  ('finally', ['0', '1']),
#  ('financial', ['0', '1']),
#  ('find', ['0', '1']),
#  ('finding', ['0', '1']),
#  ('findings', ['0', '1']),
#  ('finite', ['0', '1']),
#  ('first', ['0', '1']),
#  ('fish', ['0', '1']),
#  ('fit', ['0', '1']),
#  ('five', ['0', '1']),
#  ('fixed', ['0', '1']),
#  ('flexibility', ['0', '1']),
#  ('flexible', ['0', '1']),
#  ('flow', ['0', '1']),
#  ('fluctuations', ['0', '1']),
#  ('fluid', ['0', '1']),
#  ('fock', ['0', '1']),
#  ('focus', ['0', '1']),
#  ('focused', ['0', '1']),
#  ('focuses', ['0', '1']),
#  ('focusing', ['0', '1']),
#  ('follow', ['0', '1']),
#  ('followed', ['0', '1']),
#  ('following', ['0', '1']),
#  ('follows', ['0', '1']),
#  ('for', ['0', '1']),
#  ('force', ['0', '1']),
#  ('forces', ['0', '1']),
#  ('form', ['0', '1']),
#  ('formal', ['0', '1']),
#  ('format', ['0', '1']),
#  ('formation', ['0', '1']),
#  ('formed', ['0', '1']),
#  ('forms', ['0', '1']),
#  ('found', ['0', '1']),
#  ('foundation', ['0', '1']),
#  ('four', ['0', '1']),
#  ('fraction', ['0', '1']),
#  ('fragments', ['0', '1']),
#  ('framework', ['0', '1']),
#  ('free', ['0', '1']),
#  ('frequencies', ['0', '1']),
#  ('frequency', ['0', '1']),
#  ('frequently', ['0', '1']),
#  ('from', ['0', '1']),
#  ('full', ['0', '1']),
#  ('fully', ['0', '1']),
#  ('function', ['0', '1']),
#  ('functional', ['0', '1']),
#  ('functionality', ['0', '1']),
#  ('functions', ['0', '1']),
#  ('fundamental', ['0', '1']),
#  ('further', ['0', '1']),
#  ('furthermore', ['0', '1']),
#  ('future', ['0', '1']),
#  ('g', ['0', '1']),
#  ('game', ['0', '1']),
#  ('games', ['0', '1']),
#  ('gap', ['0', '1']),
#  ('gas', ['0', '1']),
#  ('gaussian', ['0', '1']),
#  ('gene', ['0', '1']),
#  ('general', ['0', '1']),
#  ('generalized', ['0', '1']),
#  ('generally', ['0', '1']),
#  ('generate', ['0', '1']),
#  ('generated', ['0', '1']),
#  ('generating', ['0', '1']),
#  ('generation', ['0', '1']),
#  ('generic', ['0', '1']),
#  ('genes', ['0', '1']),
#  ('genetic', ['0', '1']),
#  ('genome', ['0', '1']),
#  ('geometry', ['0', '1']),
#  ('give', ['0', '1']),
#  ('given', ['0', '1']),
#  ('gives', ['0', '1']),
#  ('glass', ['0', '1']),
#  ('global', ['0', '1']),
#  ('glucose', ['0', '1']),
#  ('go', ['0', '1']),
#  ('goal', ['0', '1']),
#  ('goals', ['0', '1']),
#  ('good', ['0', '1']),
#  ('gradient', ['0', '1']),
#  ('graph', ['0', '1']),
#  ('graphical', ['0', '1']),
#  ('graphs', ['0', '1']),
#  ('great', ['0', '1']),
#  ('greater', ['0', '1']),
#  ('ground', ['0', '1']),
#  ('group', ['0', '1']),
#  ('groups', ['0', '1']),
#  ('growing', ['0', '1']),
#  ('growth', ['0', '1']),
#  ('guide', ['0', '1']),
#  ('h', ['0', '1']),
#  ('had', ['0', '1']),
#  ('half', ['0', '1']),
#  ('hand', ['0', '1']),
#  ('hard', ['0', '1']),
#  ('hartree', ['0', '1']),
#  ('has', ['0', '1']),
#  ('have', ['0', '1']),
#  ('having', ['0', '1']),
#  ('he', ['0', '1']),
#  ('health', ['0', '1']),
#  ('help', ['0', '1']),
#  ('hence', ['0', '1']),
#  ('here', ['0', '1']),
#  ('heterogeneous', ['0', '1']),
#  ('hierarchical', ['0', '1']),
#  ('high', ['0', '1']),
#  ('higher', ['0', '1']),
#  ('highly', ['0', '1']),
#  ('his', ['0', '1']),
#  ('historical', ['0', '1']),
#  ('history', ['0', '1']),
#  ('homogeneous', ['0', '1']),
#  ('how', ['0', '1']),
#  ('however', ['0', '1']),
#  ('http', ['0', '1']),
#  ('human', ['0', '1']),
#  ('hybrid', ['0', '1']),
#  ('hydrogen', ['0', '1']),
#  ('hypermedia', ['0', '1']),
#  ('hypothesis', ['0', '1']),
#  ('i', ['0', '1']),
#  ('idea', ['0', '1']),
#  ('ideas', ['0', '1']),
#  ('identical', ['0', '1']),
#  ('identification', ['0', '1']),
#  ('identified', ['0', '1']),
#  ('identify', ['0', '1']),
#  ('identifying', ['0', '1']),
#  ('identity', ['0', '1']),
#  ('ieee', ['0', '1']),
#  ('if', ['0', '1']),
#  ('ii', ['0', '1']),
#  ('iii', ['0', '1']),
#  ('illustrate', ['0', '1']),
#  ('illustrated', ['0', '1']),
#  ('im', ['0', '1']),
#  ('image', ['0', '1']),
#  ('images', ['0', '1']),
#  ('imaging', ['0', '1']),
#  ('immobilized', ['0', '1']),
#  ('immunoassay', ['0', '1']),
#  ('impact', ['0', '1']),
#  ('implement', ['0', '1']),
#  ('implementation', ['0', '1']),
#  ('implemented', ['0', '1']),
#  ('implications', ['0', '1']),
#  ('importance', ['0', '1']),
#  ('important', ['0', '1']),
#  ('improve', ['0', '1']),
#  ('improved', ['0', '1']),
#  ('improvement', ['0', '1']),
#  ('improvements', ['0', '1']),
#  ('improving', ['0', '1']),
#  ('in', ['0', '1']),
#  ('include', ['0', '1']),
#  ('included', ['0', '1']),
#  ('includes', ['0', '1']),
#  ('including', ['0', '1']),
#  ('increase', ['0', '1']),
#  ('increased', ['0', '1']),
#  ('increases', ['0', '1']),
#  ('increasing', ['0', '1']),
#  ('increasingly', ['0', '1']),
#  ('indeed', ['0', '1']),
#  ('independent', ['0', '1']),
#  ('index', ['0', '1']),
#  ('indexing', ['0', '1']),
#  ('indicate', ['0', '1']),
#  ('indicated', ['0', '1']),
#  ('indicates', ['0', '1']),
#  ('indicating', ['0', '1']),
#  ('individual', ['0', '1']),
#  ('individuals', ['0', '1']),
#  ('induced', ['0', '1']),
#  ('industrial', ['0', '1']),
#  ('industry', ['0', '1']),
#  ('infinite', ['0', '1']),
#  ('influence', ['0', '1']),
#  ('information', ['0', '1']),
#  ('infrastructure', ['0', '1']),
#  ('initial', ['0', '1']),
#  ('initio', ['0', '1']),
#  ('innovation', ['0', '1']),
#  ('input', ['0', '1']),
#  ('insight', ['0', '1']),
#  ('insights', ['0', '1']),
#  ('instance', ['0', '1']),
#  ('instead', ['0', '1']),
#  ('institute', ['0', '1']),
#  ('int', ['0', '1']),
#  ('integrate', ['0', '1']),
#  ('integrated', ['0', '1']),
#  ('integrating', ['0', '1']),
#  ('integration', ['0', '1']),
#  ('intelligence', ['0', '1']),
#  ('intelligent', ['0', '1']),
#  ('intended', ['0', '1']),
#  ('interact', ['0', '1']),
#  ('interacting', ['0', '1']),
#  ('interaction', ['0', '1']),
#  ('interactions', ['0', '1']),
#  ('interactive', ['0', '1']),
#  ('interest', ['0', '1']),
#  ('interesting', ['0', '1']),
#  ('interface', ['0', '1']),
#  ('interfaces', ['0', '1']),
#  ('intermediate', ['0', '1']),
#  ('internal', ['0', '1']),
#  ('international', ['0', '1']),
#  ('internet', ['0', '1']),
#  ('interpretation', ['0', '1']),
#  ('into', ['0', '1']),
#  ('intrinsic', ['0', '1']),
#  ('introduce', ['0', '1']),
#  ('introduced', ['0', '1']),
#  ('introduces', ['0', '1']),
#  ('introduction', ['0', '1']),
#  ('investigate', ['0', '1']),
#  ('investigated', ['0', '1']),
#  ('investigation', ['0', '1']),
#  ('involved', ['0', '1']),
#  ('involves', ['0', '1']),
#  ('involving', ['0', '1']),
#  ('ion', ['0', '1']),
#  ('ions', ['0', '1']),
#  ('is', ['0', '1']),
#  ('isolated', ['0', '1']),
#  ('issue', ['0', '1']),
#  ('issues', ['0', '1']),
#  ('ist', ['0', '1']),
#  ('it', ['0', '1']),
#  ('items', ['0', '1']),
#  ('its', ['0', '1']),
#  ('itself', ['0', '1']),
#  ('iupap', ['0', '1']),
#  ('j', ['0', '1']),
#  ('joint', ['0', '1']),
#  ('journal', ['0', '1']),
#  ('just', ['0', '1']),
#  ('k', ['0', '1']),
#  ('key', ['0', '1']),
#  ('kind', ['0', '1']),
#  ('kinds', ['0', '1']),
#  ('kinetic', ['0', '1']),
#  ('kinetics', ['0', '1']),
#  ('know', ['0', '1']),
#  ('knowledge', ['0', '1']),
#  ('known', ['0', '1']),
#  ('l', ['0', '1']),
#  ('la', ['0', '1']),
#  ('labeled', ['0', '1']),
#  ('lack', ['0', '1']),
#  ('language', ['0', '1']),
#  ('languages', ['0', '1']),
#  ('large', ['0', '1']),
#  ('largely', ['0', '1']),
#  ('larger', ['0', '1']),
#  ('last', ['0', '1']),
#  ('latent', ['0', '1']),
#  ('later', ['0', '1']),
#  ('latter', ['0', '1']),
#  ('lattice', ['0', '1']),
#  ('law', ['0', '1']),
#  ('laws', ['0', '1']),
#  ('layer', ['0', '1']),
#  ('ldl', ['0', '1']),
#  ('lead', ['0', '1']),
#  ('leading', ['0', '1']),
#  ('leads', ['0', '1']),
#  ('learn', ['0', '1']),
#  ('learned', ['0', '1']),
#  ('learning', ['0', '1']),
#  ('least', ['0', '1']),
#  ('led', ['0', '1']),
#  ('left', ['0', '1']),
#  ('length', ['0', '1']),
#  ('less', ['0', '1']),
#  ('lett', ['0', '1']),
#  ('letters', ['0', '1']),
#  ('level', ['0', '1']),
#  ('levels', ['0', '1']),
#  ('libraries', ['0', '1']),
#  ('library', ['0', '1']),
#  ...]

# %%
X_dense= X.todense()

# %%
x= X_dense[0]

# %%
len(x.tolist())
# Out:
# 1

# %%
X, y, feature_names, label_names =load_from_arff('../.data/imdb_meka/all.arff', label_count=28, return_attribute_definitions=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-35af5cbd1173> in <module>
# ----> 1 X, y, feature_names, label_names =load_from_arff('../.data/imdb_meka/all.arff',  return_attribute_definitions=True)
#
# TypeError: load_from_arff() missing 1 required positional argument: 'label_count'

# %%
X=X.todense()

# %%
label_names
# Out:
# [('Sci-Fi', ['0', '1']),
#  ('Crime', ['0', '1']),
#  ('Romance', ['0', '1']),
#  ('Animation', ['0', '1']),
#  ('Music', ['0', '1']),
#  ('Comedy', ['0', '1']),
#  ('War', ['0', '1']),
#  ('Horror', ['0', '1']),
#  ('Film-Noir', ['0', '1']),
#  ('Adventure', ['0', '1']),
#  ('News', ['0', '1']),
#  ('Western', ['0', '1']),
#  ('Thriller', ['0', '1']),
#  ('Adult', ['0', '1']),
#  ('Mystery', ['0', '1']),
#  ('Short', ['0', '1']),
#  ('Talk-Show', ['0', '1']),
#  ('Drama', ['0', '1']),
#  ('Action', ['0', '1']),
#  ('Documentary', ['0', '1']),
#  ('Musical', ['0', '1']),
#  ('History', ['0', '1']),
#  ('Family', ['0', '1']),
#  ('Reality-TV', ['0', '1']),
#  ('Fantasy', ['0', '1']),
#  ('Game-Show', ['0', '1']),
#  ('Sport', ['0', '1']),
#  ('Biography', ['0', '1'])]

# %%
if __name__=="__main__":
    main()

# %%
import numpy as np

# %%
def dataset(
    x: np.ndarray,
    y: np.ndarray,
    feature_names: List[Tuple[str, Any]],
    label_names: List[Tuple[str, Any]],
) -> List[Dict]:
    num_features = len(feature_names)
    assert x.shape[-1] == num_features
    num_total_labels = len(label_names)
    assert y.shape[-1] == num_total_labels
    all_labels = np.array([l[0] for l in label_names])
    data = [{'x': xi.tolist(), 'y': (all_labels[yi ==1]).tolist()} for xi, yi in zip(x, y)]
    return data

# %%
imdb = dataset(X.toarray(),y.toarray(), feature_names, label_names)

# %%
len(imdb[1]['x'])
# Out:
# 1001

# %%
def cardinality(y: List[List])->float:
    return np.mean([len(i) for i in y])

# %%
cardinality([i['y'] for i in imdb ])
# Out:
# 1.999669200043004

# %%
def diversity(y: List[List]) -> float:
    vocab = set([v for l in y for v in l])
    l2i = {label: i for i, label in enumerate(vocab)}
    i2l = {i: label for label, i in l2i.items()}
    label_sets_present = set()
    for yi in y:
        yi_onehot = [0]*len(vocab)
        for label in yi:
            yi_onehot[l2i[label]]=1
        label_sets_present.add(tuple(yi_onehot))
    return len(label_sets_present)/np.power(2, len(vocab))

# %%
diversity([i['y'] for i in imdb])
# Out:
# 1.6774982213974e-05

# %%
from allennlp.data
